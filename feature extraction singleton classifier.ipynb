# %%
import pandas as pd
import csv
import numpy as np
import xml.etree.ElementTree as ET

# %%
class UFDS:
    def __init__(self):
        self.nodes = set()
        self.parent = {}
    
    def init_id(self, *nodes):
        for node in nodes:
            if node not in self.nodes:
                self.nodes.add(node)
                self.parent[node] = node
        
    def root(self, x):
        self.init_id(x)
        
        if self.parent[x] == x:
            return x
        else:
            self.parent[x] = self.root(self.parent[x])
            return self.parent[x]
    
    def gabung(self, x, y):
        self.init_id(x, y)
        
        self.parent[self.root(x)] = self.root(y)
    
    def is_same(self, x, y):
        self.init_id(x, y)
        
        return self.root(x) == self.root(y)

# %%
data = ET.parse('./data.xml')
root = data.getroot()

# %%
ufds = UFDS()
nodes = {}
phrases = []
phrase_id_by_node_id = {}

# %%
for sentence in root:
    for phrase in sentence:
        phrases.append(phrase)
        
        if 'id' in phrase.attrib:
            ufds.init_id(int(phrase.attrib['id']))
            nodes[int(phrase.attrib['id'])] = phrase
            phrase_id_by_node_id[int(phrase.attrib['id'])] = len(phrases) - 1
        
        if 'coref' in phrase.attrib:
            ufds.gabung(int(phrase.attrib['id']), int(phrase.attrib['coref']))

# %%
kelompok = {}

for node in ufds.nodes:
    if ufds.root(node) not in kelompok:
        kelompok[ufds.root(node)] = []
    
    kelompok[ufds.root(node)].append(node)

def is_singleton(node):
    par = ufds.root(node)
    return len(kelompok[par]) == 1

# %%
def get_pos_tag(word):
    return word.split('\\')[-1]

# %%
def get_previous_words(phrase_id, n):
    if phrase_id < 0 or n == 0:
        return []
    
    words = phrases[phrase_id].text.split()
    
    if len(words) <= n:
        return get_previous_words(phrase_id - 1, n - len(words)) + words
    else:
        return words[(-1*n):]

def get_next_words(phrase_id, n):
    if phrase_id >= len(phrases) or n == 0:
        return []
    
    words = phrases[phrase_id].text.split()
    
    if len(words) <= n:
        return words + get_next_words(phrase_id + 1, n - len(words))
    else:
        return words[:n]

# %%
markables = [{
    'id': int(node.attrib['id']),
    'text': node.text,
#     'nominal': '',o
    'num_words': len(node.text.split()),
#     'num_modifiers': '',
    'first_pos_tag': get_pos_tag(node.text.split()[0]),
#     'is_pronoun': '',
    'entity': node.attrib['ne'],
    'is_singleton': is_singleton(int(node.attrib['id'])),
    'previous_words': get_previous_words(phrase_id_by_node_id[int(node.attrib['id'])] - 1, 10),
    'next_words': get_next_words(phrase_id_by_node_id[int(node.attrib['id'])] + 1, 10)
} for node in nodes.values()]

# %%
markables[1:10]
# Out:
# [{'id': 2,
#   'text': 'pesta\\NN olahraga\\NN',
#   'num_words': 2,
#   'first_pos_tag': 'NN',
#   'entity': 'OTHER',
#   'is_singleton': True,
#   'previous_words': ['Kera\\NN', 'untuk\\SC', 'amankan\\VB'],
#   'next_words': ['Pemerintah\\NNP',
#    'kota\\NNP',
#    'Delhi\\NNP',
#    'mengerahkan\\VB',
#    'monyet\\NN',
#    'untuk\\SC',
#    'mengusir\\VB',
#    'monyet-monyet\\NN',
#    'lain\\JJ',
#    'yang\\SC']},
#  {'id': 3,
#   'text': 'Pemerintah\\NNP kota\\NNP Delhi\\NNP',
#   'num_words': 3,
#   'first_pos_tag': 'NNP',
#   'entity': 'TITLE|LOCATION',
#   'is_singleton': False,
#   'previous_words': ['Kera\\NN',
#    'untuk\\SC',
#    'amankan\\VB',
#    'pesta\\NN',
#    'olahraga\\NN'],
#   'next_words': ['mengerahkan\\VB',
#    'monyet\\NN',
#    'untuk\\SC',
#    'mengusir\\VB',
#    'monyet-monyet\\NN',
#    'lain\\JJ',
#    'yang\\SC',
#    'berbadan\\VB',
#    'lebih\\RB',
#    'kecil\\JJ']},
#  {'id': 4,
#   'text': 'monyet\\NN',
#   'num_words': 1,
#   'first_pos_tag': 'NN',
#   'entity': 'OTHER',
#   'is_singleton': True,
#   'previous_words': ['Kera\\NN',
#    'untuk\\SC',
#    'amankan\\VB',
#    'pesta\\NN',
#    'olahraga\\NN',
#    'Pemerintah\\NNP',
#    'kota\\NNP',
#    'Delhi\\NNP',
#    'mengerahkan\\VB'],
#   'next_words': ['untuk\\SC',
#    'mengusir\\VB',
#    'monyet-monyet\\NN',
#    'lain\\JJ',
#    'yang\\SC',
#    'berbadan\\VB',
#    'lebih\\RB',
#    'kecil\\JJ',
#    'dari\\IN',
#    'arena\\NN']},
#  {'id': 5,
#   'text': 'monyet-monyet\\NN lain\\JJ',
#   'num_words': 2,
#   'first_pos_tag': 'NN',
#   'entity': 'OTHER',
#   'is_singleton': True,
#   'previous_words': ['amankan\\VB',
#    'pesta\\NN',
#    'olahraga\\NN',
#    'Pemerintah\\NNP',
#    'kota\\NNP',
#    'Delhi\\NNP',
#    'mengerahkan\\VB',
#    'monyet\\NN',
#    'untuk\\SC',
#    'mengusir\\VB'],
#   'next_words': ['yang\\SC',
#    'berbadan\\VB',
#    'lebih\\RB',
#    'kecil\\JJ',
#    'dari\\IN',
#    'arena\\NN',
#    'Pesta\\NNP',
#    'Olahraga\\NNP',
#    'Persemakmuran.\\NNP',
#    'Beberapa\\CD']},
#  {'id': 6,
#   'text': 'Pesta\\NNP Olahraga\\NNP Persemakmuran.\\NNP',
#   'num_words': 3,
#   'first_pos_tag': 'NNP',
#   'entity': 'FACILITY|OTHER',
#   'is_singleton': True,
#   'previous_words': ['untuk\\SC',
#    'mengusir\\VB',
#    'monyet-monyet\\NN',
#    'lain\\JJ',
#    'yang\\SC',
#    'berbadan\\VB',
#    'lebih\\RB',
#    'kecil\\JJ',
#    'dari\\IN',
#    'arena\\NN'],
#   'next_words': ['Beberapa\\CD',
#    'laporan\\NN',
#    'menyebutkan\\VB',
#    'setidaknya\\RB',
#    '10\\CD',
#    'monyet\\NN',
#    'ditempatkan\\VB',
#    'di\\IN',
#    'luar\\NN',
#    'arena\\NN']},
#  {'id': 7,
#   'text': 'Beberapa\\CD laporan\\NN',
#   'num_words': 2,
#   'first_pos_tag': 'CD',
#   'entity': 'OTHER',
#   'is_singleton': True,
#   'previous_words': ['lain\\JJ',
#    'yang\\SC',
#    'berbadan\\VB',
#    'lebih\\RB',
#    'kecil\\JJ',
#    'dari\\IN',
#    'arena\\NN',
#    'Pesta\\NNP',
#    'Olahraga\\NNP',
#    'Persemakmuran.\\NNP'],
#   'next_words': ['menyebutkan\\VB',
#    'setidaknya\\RB',
#    '10\\CD',
#    'monyet\\NN',
#    'ditempatkan\\VB',
#    'di\\IN',
#    'luar\\NN',
#    'arena\\NN',
#    'lomba\\NN',
#    'dan\\CC']},
#  {'id': 8,
#   'text': 'setidaknya\\RB 10\\CD monyet\\NN',
#   'num_words': 3,
#   'first_pos_tag': 'RB',
#   'entity': 'OTHER|NUM',
#   'is_singleton': True,
#   'previous_words': ['lebih\\RB',
#    'kecil\\JJ',
#    'dari\\IN',
#    'arena\\NN',
#    'Pesta\\NNP',
#    'Olahraga\\NNP',
#    'Persemakmuran.\\NNP',
#    'Beberapa\\CD',
#    'laporan\\NN',
#    'menyebutkan\\VB'],
#   'next_words': ['ditempatkan\\VB',
#    'di\\IN',
#    'luar\\NN',
#    'arena\\NN',
#    'lomba\\NN',
#    'dan\\CC',
#    'pertandingan\\NN',
#    'di\\IN',
#    'ibukota\\NNP',
#    'India.\\NNP']},
#  {'id': 9,
#   'text': 'lomba\\NN dan\\CC pertandingan\\NN',
#   'num_words': 3,
#   'first_pos_tag': 'NN',
#   'entity': 'THINGS',
#   'is_singleton': True,
#   'previous_words': ['Beberapa\\CD',
#    'laporan\\NN',
#    'menyebutkan\\VB',
#    'setidaknya\\RB',
#    '10\\CD',
#    'monyet\\NN',
#    'ditempatkan\\VB',
#    'di\\IN',
#    'luar\\NN',
#    'arena\\NN'],
#   'next_words': ['di\\IN',
#    'ibukota\\NNP',
#    'India.\\NNP',
#    'Pemkot\\NNP',
#    'Delhi\\NNP',
#    'memiliki\\VB',
#    '28\\CD',
#    'monyet\\NN',
#    'dan\\CC',
#    'berencana\\VB']},
#  {'id': 10,
#   'text': 'ibukota\\NNP India.\\NNP',
#   'num_words': 2,
#   'first_pos_tag': 'NNP',
#   'entity': 'OTHER',
#   'is_singleton': False,
#   'previous_words': ['10\\CD',
#    'monyet\\NN',
#    'ditempatkan\\VB',
#    'di\\IN',
#    'luar\\NN',
#    'arena\\NN',
#    'lomba\\NN',
#    'dan\\CC',
#    'pertandingan\\NN',
#    'di\\IN'],
#   'next_words': ['Pemkot\\NNP',
#    'Delhi\\NNP',
#    'memiliki\\VB',
#    '28\\CD',
#    'monyet\\NN',
#    'dan\\CC',
#    'berencana\\VB',
#    'mendatangkan\\VB',
#    '10\\CD',
#    'monyet\\NN']}]

# %%
zzz = [[nodes[i].text for i in j] for j in kelompok.values()]

# %%
with open('markables.csv', 'w') as f:
    csvfile = csv.DictWriter(f, fieldnames=markables[0].keys())
    csvfile.writeheader()
    csvfile.writerows(markables)
